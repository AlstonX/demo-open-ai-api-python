# %% [markdown]
# # OpenAI API Python Demo
#
# This notebook demonstrates the project by importing the standalone Python files in this repository.

# %% [markdown]
# ## Import Demo Modules

# %%
from openai_client import create_client, load_api_key
from simple_call import ask_nyc_24_hours
from temperature_demo import get_response
from chat_with_history import ChatWithHistory

# %% [markdown]
# ## Check Client Setup

# %%
client = create_client()
print("OpenAI client is ready.")

# %% [markdown]
# ## Run A Simple API Call

# %%
print(ask_nyc_24_hours())

# %% [markdown]
# ## Compare Temperature Values

# %%
temperatures = [0.2, 0.5, 0.8]

for temperature in temperatures:
    print("temperature:", temperature)
    print(get_response(client, temperature))
    print()

# %% [markdown]
# ## Chat With History

# %%
chatbot = ChatWithHistory(load_api_key())

chatbot.chat("Give me a one sentence travel tip for New York City.")
chatbot.chat("Make that tip cheaper.")

# %% [markdown]
# Use `chatbot.clear()` if you want to reset the chat history.
